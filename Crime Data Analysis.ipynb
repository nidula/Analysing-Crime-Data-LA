# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
project_directory = '/content/drive/MyDrive/Analytic Tools/'

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# ## Importing the Crime_Data_from_2010_to_2019.csv Dataset

# %%
df = pd.read_csv(project_directory+'/Crime_Data_from_2010_to_2019.csv')

# %%
df
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0          1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350
# 1         11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45
# 2         70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515
# 3         90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150
# 4        100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100
# ...            ...                     ...                     ...       ...
# 2119792  190506304  02/22/2019 12:00:00 AM  02/22/2019 12:00:00 AM       840
# 2119793  190608903  03/28/2019 12:00:00 AM  03/28/2019 12:00:00 AM       400
# 2119794  192004409  01/06/2019 12:00:00 AM  01/06/2019 12:00:00 AM      2100
# 2119795  191716777  10/17/2019 12:00:00 AM  10/16/2019 12:00:00 AM      1800
# 2119796  190805435  02/01/2019 12:00:00 AM  02/01/2019 12:00:00 AM      1615
#
#          AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0           13      Newton         1385         2     900
# 1           14     Pacific         1485         2     740
# 2           13      Newton         1324         2     946
# 3            6   Hollywood          646         2     900
# 4            1     Central          176         1     122
# ...        ...         ...          ...       ...     ...
# 2119792      5      Harbor          569         2     627
# 2119793      6   Hollywood          644         1     648
# 2119794     20     Olympic         2029         2     930
# 2119795     17  Devonshire         1795         1     420
# 2119796      8     West LA          852         1     330
#
#                                                Crm Cd Desc  ... Status  \
# 0                                 VIOLATION OF COURT ORDER  ...     AA
# 1        VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 2                                OTHER MISCELLANEOUS CRIME  ...     IC
# 3                                 VIOLATION OF COURT ORDER  ...     IC
# 4                                          RAPE, ATTEMPTED  ...     IC
# ...                                                    ...  ...    ...
# 2119792            CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT  ...     AO
# 2119793                                              ARSON  ...     IC
# 2119794             CRIMINAL THREATS - NO WEAPON DISPLAYED  ...     IC
# 2119795    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)  ...     IC
# 2119796                              BURGLARY FROM VEHICLE  ...     IC
#
#           Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0        Adult Arrest    900.0      NaN       NaN      NaN
# 1         Invest Cont    740.0      NaN       NaN      NaN
# 2         Invest Cont    946.0      NaN       NaN      NaN
# 3         Invest Cont    900.0    998.0       NaN      NaN
# 4         Invest Cont    122.0      NaN       NaN      NaN
# ...               ...      ...      ...       ...      ...
# 2119792   Adult Other    627.0      NaN       NaN      NaN
# 2119793   Invest Cont    648.0      NaN       NaN      NaN
# 2119794   Invest Cont    930.0      NaN       NaN      NaN
# 2119795   Invest Cont    420.0      NaN       NaN      NaN
# 2119796   Invest Cont    330.0      NaN       NaN      NaN
#
#                                          LOCATION  \
# 0          300 E  GAGE                         AV
# 1                 SEPULVEDA                    BL
# 2         1300 E  21ST                         ST
# 3                 CAHUENGA                     BL
# 4                 8TH                          ST
# ...                                           ...
# 2119792    100 W  22ND                         ST
# 2119793   1400 N  LA BREA                      AV
# 2119794                                       6TH
# 2119795  17200    NAPA                         ST
# 2119796   1700    BARRY                        AV
#
#                             Cross Street      LAT       LON
# 0                                    NaN  33.9825 -118.2695
# 1        MANCHESTER                   AV  33.9599 -118.3962
# 2                                    NaN  34.0224 -118.2524
# 3        HOLLYWOOD                    BL  34.1016 -118.3295
# 4        SAN PEDRO                    ST  34.0387 -118.2488
# ...                                  ...      ...       ...
# 2119792                              NaN  33.7257 -118.2801
# 2119793                              NaN  34.0962 -118.3490
# 2119794                           VIRGIL  34.0637 -118.2870
# 2119795                              NaN  34.2266 -118.5085
# 2119796                              NaN  34.0420 -118.4531
#
# [2119797 rows x 28 columns]

# %%
df.nunique()
# Out:
# DR_NO             2119797
# Date Rptd            4497
# DATE OCC             3652
# TIME OCC             1439
# AREA                   21
# AREA NAME              21
# Rpt Dist No          1303
# Part 1-2                2
# Crm Cd                142
# Crm Cd Desc           142
# Mocodes            486164
# Vict Age              112
# Vict Sex                6
# Vict Descent           20
# Premis Cd             325
# Premis Desc           320
# Weapon Used Cd         80
# Weapon Desc            79
# Status                  9
# Status Desc             6
# Crm Cd 1              148
# Crm Cd 2              143
# Crm Cd 3               63
# Crm Cd 4               12
# LOCATION            75540
# Cross Street        12878
# LAT                  5437
# LON                  5097
# dtype: int64

# %%
df.rename(columns={'Crm Cd Desc': 'Crm_Cd_Desc'}, inplace=True)

# %%
df.Crm_Cd_Desc.unique()
# Out:
# array(['VIOLATION OF COURT ORDER',
#        'VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)',
#        'OTHER MISCELLANEOUS CRIME', 'RAPE, ATTEMPTED',
#        'SHOPLIFTING - PETTY THEFT ($950 & UNDER)',
#        'BURGLARY FROM VEHICLE',
#        'ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT',
#        'THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD',
#        'BATTERY - SIMPLE ASSAULT', 'ROBBERY', 'BOMB SCARE',
#        'CHILD NEGLECT (SEE 300 W.I.C.)',
#        'INTIMATE PARTNER - AGGRAVATED ASSAULT',
#        'INTIMATE PARTNER - SIMPLE ASSAULT',
#        'THEFT PLAIN - PETTY ($950 & UNDER)',
#        'CRIMINAL THREATS - NO WEAPON DISPLAYED', 'ATTEMPTED ROBBERY',
#        'VANDALISM - MISDEAMEANOR ($399 OR UNDER)', 'BURGLARY', 'ARSON',
#        'RAPE, FORCIBLE', 'BRANDISH WEAPON',
#        'THROWING OBJECT AT MOVING VEHICLE',
#        'SHOPLIFTING-GRAND THEFT ($950.01 & OVER)',
#        'CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT',
#        'SHOTS FIRED AT INHABITED DWELLING', 'VEHICLE - STOLEN',
#        'KIDNAPPING - GRAND ATTEMPT', 'CRIMINAL HOMICIDE',
#        'THEFT PLAIN - ATTEMPT', 'THEFT, PERSON', 'TRESPASSING',
#        'KIDNAPPING', 'VEHICLE - ATTEMPT STOLEN',
#        'BATTERY WITH SEXUAL CONTACT', 'DOCUMENT FORGERY / STOLEN FELONY',
#        'BATTERY POLICE (SIMPLE)',
#        'CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT',
#        'DISTURBING THE PEACE', 'OTHER ASSAULT',
#        'VIOLATION OF RESTRAINING ORDER', 'LEWD CONDUCT',
#        'CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)',
#        'THEFT OF IDENTITY',
#        'ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER',
#        'CHILD ANNOYING (17YRS & UNDER)',
#        'SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH',
#        'ORAL COPULATION', 'CRUELTY TO ANIMALS',
#        'THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)',
#        'LETTERS, LEWD  -  TELEPHONE CALLS, LEWD', 'PEEPING TOM',
#        'INDECENT EXPOSURE', 'BIKE - STOLEN',
#        'BURGLARY FROM VEHICLE, ATTEMPTED', 'BURGLARY, ATTEMPTED',
#        'STALKING', 'THREATENING PHONE CALLS/LETTERS',
#        'SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ',
#        'BUNCO, PETTY THEFT', 'BUNCO, GRAND THEFT',
#        'VIOLATION OF TEMPORARY RESTRAINING ORDER',
#        'EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)',
#        'SEXUAL PENETRATION W/FOREIGN OBJECT', 'EXTORTION', 'PICKPOCKET',
#        'EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)', 'PURSE SNATCHING',
#        'WEAPONS POSSESSION/BOMBING', 'COUNTERFEIT', 'FALSE IMPRISONMENT',
#        'CREDIT CARDS, FRAUD USE ($950.01 & OVER)',
#        'DISCHARGE FIREARMS/SHOTS FIRED', 'THEFT FROM PERSON - ATTEMPT',
#        'UNAUTHORIZED COMPUTER ACCESS', 'PANDERING', 'PIMPING',
#        'DRUNK ROLL - ATTEMPT', 'SHOPLIFTING - ATTEMPT',
#        'RESISTING ARREST', 'DISHONEST EMPLOYEE - GRAND THEFT',
#        'RECKLESS DRIVING', 'PROWLER',
#        'CREDIT CARDS, FRAUD USE ($950 & UNDER',
#        'DOCUMENT WORTHLESS ($200.01 & OVER)', 'CHILD STEALING',
#        'CONTEMPT OF COURT', 'CONSPIRACY',
#        'THEFT FROM MOTOR VEHICLE - ATTEMPT', 'DRUNK ROLL',
#        'BATTERY ON A FIREFIGHTER', 'ILLEGAL DUMPING', 'LYNCHING',
#        'THEFT, COIN MACHINE - PETTY ($950 & UNDER)',
#        'GRAND THEFT / INSURANCE FRAUD', 'BUNCO, ATTEMPT',
#        'DISRUPT SCHOOL', 'THEFT, COIN MACHINE - GRAND ($950.01 & OVER)',
#        'FALSE POLICE REPORT', 'PURSE SNATCHING - ATTEMPT',
#        'BOAT - STOLEN',
#        'SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT',
#        'DRIVING WITHOUT OWNER CONSENT (DWOC)', 'CONTRIBUTING',
#        'FAILURE TO YIELD', 'TILL TAP - ATTEMPT', 'DRUGS, TO A MINOR',
#        'INCITING A RIOT',
#        'BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT WITH ANIM',
#        'BRIBERY', 'THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)',
#        'DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 & UNDER',
#        'DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $950.01',
#        'TILL TAP - GRAND THEFT ($950.01 & OVER)', 'LYNCHING - ATTEMPTED',
#        'SEX OFFENDER REGISTRANT OUT OF COMPLIANCE', 'CHILD ABANDONMENT',
#        'LEWD/LASCIVIOUS ACTS WITH CHILD',
#        'DISHONEST EMPLOYEE - PETTY THEFT', 'TELEPHONE PROPERTY - DAMAGE',
#        'PICKPOCKET, ATTEMPT', 'TILL TAP - PETTY ($950 & UNDER)',
#        'DOCUMENT WORTHLESS ($200 & UNDER)',
#        'HUMAN TRAFFICKING - COMMERCIAL SEX ACTS',
#        'MANSLAUGHTER, NEGLIGENT', 'GRAND THEFT / AUTO REPAIR', 'BIGAMY',
#        'THEFT, COIN MACHINE - ATTEMPT', 'PETTY THEFT - AUTO REPAIR',
#        'BIKE - ATTEMPTED STOLEN', 'FAILURE TO DISPERSE',
#        'REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR DISTRIBUTE)',
#        'HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE', 'CHILD PORNOGRAPHY',
#        'ABORTION/ILLEGAL', 'INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)',
#        'DISHONEST EMPLOYEE ATTEMPTED THEFT', 'TRAIN WRECKING',
#        'BLOCKING DOOR INDUCTION CENTER',
#        'FIREARMS RESTRAINING ORDER (FIREARMS RO)',
#        'VEHICLE - MOTORIZED SCOOTERS, BICYCLES, AND WHEELCHAIRS',
#        'FIREARMS TEMPORARY RESTRAINING ORDER (TEMP FIREARMS RO)'],
#       dtype=object)

# %%
df.rename(columns={'DATE OCC': 'DATE_OCC'}, inplace=True)

# %%
df['DATE_OCC'] = pd.to_datetime(df['DATE_OCC'])

# %%
lowest_date = df['DATE_OCC'].min()
highest_date = df['DATE_OCC'].max()

print(f'Lowest date: {lowest_date}')
print(f'Highest date: {highest_date}')
# Out:
# Lowest date: 2010-01-01 00:00:00
# Highest date: 2019-12-31 00:00:00

# %% [markdown]
# ## Importing the Crime_Data_from_2020_to_Present.csv Dataset

# %%
df1 = pd.read_csv(project_directory+'/Crime_Data_from_2020_to_Present.csv')

# %%
df1
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 682330  230806871  03/03/2023 12:00:00 AM  03/02/2023 12:00:00 AM       620
# 682331  231104474  01/12/2023 12:00:00 AM  01/12/2023 12:00:00 AM      1240
# 682332  230804266  01/08/2023 12:00:00 AM  01/08/2023 12:00:00 AM      1030
# 682333  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 682334  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          3    Southwest          377         2     624
# 1          1      Central          163         2     624
# 2          1      Central          155         2     845
# 3         15  N Hollywood         1543         2     745
# 4         19      Mission         1998         2     740
# ...      ...          ...          ...       ...     ...
# 682330     8      West LA          889         2     354
# 682331    11    Northeast         1107         1     440
# 682332     8      West LA          839         1     341
# 682333    16     Foothill         1663         2     740
# 682334     9     Van Nuys          914         2     745
#
#                                               Crm Cd Desc  ... Status  \
# 0                                BATTERY - SIMPLE ASSAULT  ...     AO
# 1                                BATTERY - SIMPLE ASSAULT  ...     IC
# 2               SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# 3                VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 4       VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# ...                                                   ...  ...    ...
# 682330                                  THEFT OF IDENTITY  ...     IC
# 682331                 THEFT PLAIN - PETTY ($950 & UNDER)  ...     IC
# 682332  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...  ...     IC
# 682333  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 682334           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
#
#          Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0        Adult Other    624.0      NaN       NaN      NaN
# 1        Invest Cont    624.0      NaN       NaN      NaN
# 2       Adult Arrest    845.0      NaN       NaN      NaN
# 3        Invest Cont    745.0    998.0       NaN      NaN
# 4        Invest Cont    740.0      NaN       NaN      NaN
# ...              ...      ...      ...       ...      ...
# 682330   Invest Cont    354.0      NaN       NaN      NaN
# 682331   Invest Cont    440.0      NaN       NaN      NaN
# 682332   Invest Cont    341.0      NaN       NaN      NaN
# 682333   Invest Cont    740.0      NaN       NaN      NaN
# 682334   Invest Cont    745.0      NaN       NaN      NaN
#
#                                         LOCATION Cross Street      LAT  \
# 0        1100 W  39TH                         PL          NaN  34.0141
# 1         700 S  HILL                         ST          NaN  34.0459
# 2         200 E  6TH                          ST          NaN  34.0448
# 3        5400    CORTEEN                      PL          NaN  34.1685
# 4       14400    TITUS                        ST          NaN  34.2198
# ...                                          ...          ...      ...
# 682330   2000 S  HOLT                         AV          NaN  34.0412
# 682331   1000    MILWAUKEE                    AV          NaN  34.1214
# 682332  10200    SANTA MONICA                 BL          NaN  34.0611
# 682333  12500    BRANFORD                     ST          NaN  34.2466
# 682334  14500    HARTLAND                     ST          NaN  34.1951
#
#              LON
# 0      -118.2978
# 1      -118.2545
# 2      -118.2474
# 3      -118.4019
# 4      -118.4468
# ...          ...
# 682330 -118.3814
# 682331 -118.1915
# 682332 -118.4184
# 682333 -118.4054
# 682334 -118.4487
#
# [682335 rows x 28 columns]

# %%
df1.nunique()
# Out:
# DR_NO             682335
# Date Rptd           1168
# DATE OCC            1168
# TIME OCC            1439
# AREA                  21
# AREA NAME             21
# Rpt Dist No         1194
# Part 1-2               2
# Crm Cd               137
# Crm Cd Desc          137
# Mocodes           233172
# Vict Age             102
# Vict Sex               4
# Vict Descent          19
# Premis Cd            309
# Premis Desc          306
# Weapon Used Cd        79
# Weapon Desc           79
# Status                 6
# Status Desc            6
# Crm Cd 1             139
# Crm Cd 2             120
# Crm Cd 3              35
# Crm Cd 4               6
# LOCATION           61184
# Cross Street        9082
# LAT                 5379
# LON                 4958
# dtype: int64

# %%
df1.rename(columns={'Crm Cd Desc': 'Crm_Cd_Desc'}, inplace=True)

# %%
df1.rename(columns={'DATE OCC': 'DATE_OCC'}, inplace=True)

# %%
df1['DATE_OCC'] = pd.to_datetime(df1['DATE_OCC'])

# %%
lowest_date = df1['DATE_OCC'].min()
highest_date = df1['DATE_OCC'].max()

print(f'Lowest date: {lowest_date}')
print(f'Highest date: {highest_date}')
# Out:
# Lowest date: 2020-01-01 00:00:00
# Highest date: 2023-03-13 00:00:00
